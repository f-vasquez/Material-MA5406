# %% [markdown]
# # Proyectos I
#
# Clase de introducción a proyectos. Información sobre cómo seleccionar un proyecto y primer acercamiento a los datos.
#
# **Autor**: Francisco Vásquez
#
# **Mail**: fvasquez@dim.uchile.cl

# %% [markdown]
# # Objetivos

# %% [markdown]
# Esta es una clase enfocada a ver los siguientes aspectos de lo que es llevar a cabo un proyecto
#
#     - Elegir la problemática y dataset
#     - Flujo de un proyecto
#     - Primer acercamiento a los datos
#     - Primeros modelos
#     - Interpretación de resultados
#
# más que nada, poder ver el flujo de pensamientos al llevar un proyecto, abordando preguntas como:
#
#     ¿Y ahora qué hago?
#     ¿Qué significa esto?
#     ¿Cómo interpreto un resultado?.

# %% [markdown]
# #  Previos

# %% [markdown]
# **Lenguajes de programación**
#
# Existen distintos lenguajes de programación que son utilizados para el Data Science y Machine Learning. Si bien algunos son más cómunes que otros, en el global no hay uno que sea mejor a otro, dado que estos nos otorgan distintas cosas y tienen distintos enfoques. Enfocado en el Data Science, los lenguajes más comunes son los siguientes:
#
#     -Python
#     -R
#     -SQL
#     -Scala
#     -Excel
#
# Cada uno nos entregan herramientas potentes que pueden servir para distintas cosas. Un buen lenguaje y que en el general puede ser considerado el mejor para iniciar es Python, el cual es un lenguaje interpretado, dinámico y multiparadigma.
#
#
# **Plataformas**
#
# Para trabajar con Python existen varios Integrated Development Environments (IDEs) que nos permiten trabajar de manera cómoda y facil. Algunos de estos son:
#
#     -Jupyter Notebook
#     -Pycharm
#     -Eclipe
#     -Visual Studio
#
# Nuevamente, cada plataforma nos ofrece lo propio, con lo cual determinar cual es mejor a otra solo depende del usuario...
#
# **Librerías**
#
# En Python encontramos muchas librerías que pueden ser útiles para el DS y ML, como lo son:
#
#     Las clásicas
#     -Numpy, trabajo de "algebra lineal"
#     -Matplotlib, visualización
#
#     Especiales
#     -Pandas, trabajo de dataframes
#     -Sklearn, aprendizaje automático
#     -Seaborn, rápida visualización de datos
#
# con las librerías anteriores ya es posible realizar un buen proyecto de DS.

# %% [markdown]
# # Planeando un proyecto
#
# ## ¿Qué es lo que puedo hacer?
#
# Los algoritmos vistos son bastante generales y pueden ser aplicados a distintos problemas de la vida real. Veamos algunos ejemplos:
#
#     Clusterización:
#         - Clusterización aplicada a encuestas
#         - Segmentación de clientes
#         - Clusterización de imágenes
#
#     Regresión:
#         - Predecir cantidad de muertos covid
#         - Predecir ganancias, índices, etc.
#         - Predecir tiempo en realizar algún proceso
#         - etc
#
#     Clasificación:
#         - Clasificación binaria:
#             - Predecir resultados de un exámen
#             - Obtención de probabilidades de propensión (riesgo)
#         - Multi Clasificación:
#             - Predicción de intensidad de sentimientos
#             - Predicción de
#
#     Análisis de Variables:
#         -Variables relevantes para cierta predicción

# %% [markdown]
# ## ¿Primero los datos o la pregunta?

# %% [markdown]
# Es una pregunta bastante importante al inicio de cada estudio. Como en todos los casos de trabajo en datos, **siempre depende de lo que quiere hacer y de lo que se tiene**.
#
# Mi recomendación: búsquen datasets, estudien las variables e intenten plantear preguntas.

# %% [markdown]
# ## ¿De dónde puedo obtener los datos?

# %% [markdown]
# Hay muchos lados de dónde se pueden obtener datos y de fácil obtención. Datos de encuestas, estadísticas, bases obtenidas por web-scraping etc. Algunas de las páginas más conocidas son:
#
#     Kaggle: www.kaggle.com
#     UCI ML Repository: https://archive.ics.uci.edu/ml/index.php
#     Amazon Datasets: https://registry.opendata.aws/
#     Google Dataset Search: https://datasetsearch.research.google.com/
#     Awesome Datasets: https://github.com/awesomedata/awesome-public-datasets
#     Microsoft Open Data: https://msropendata.com/
#     Visual Data: https://www.visualdata.io/discovery

# %% [markdown]
# ## Flujo General

# %% [markdown]
# En un proyecto

# %% [markdown]
# Para implementar un proyecto de este tipo, es necesario tener en cuenta algunos pasos generales para poder definir cómo continuar con el trabajo, estos pasos generales **pueden** ser:
#
#     1. Comprensión del problema
#     1.1 Entender el contexto
#     1.2 Definir el problema
#
#     2. Trabajo de datos
#     2.1 Recolección de datos
#     2.2 Limpieza de datos
#     2.3 Entender los datos, Exploratory Data Analysys (EDA)
#     2.4 Preparación de los datos
#
#     3. Implementación del modelo
#     3.1 Modelo
#     3.2 Evaluación
#     3.3 Deployment (Este no lo consideraremos)
#
#     4. Global
#     4.1 Feedback
#
# Esto lo podemos ver visualmente en el siguiente diagrama:

# %% [markdown]
# ![diagrama_proyecto.png](attachment:diagrama_proyecto.png)

# %% [markdown]
# donde cada flecha indica un flujo posible a seguir para poder obtener un proyecto. Notar que existen varias flechas que nos envían hacía atrás, esto es porque en un proyecto es muy importante **iterar**, tanto las ideas como los pasos.

# %% [markdown]
# Algo importante a considerar y que hay que preguntarse en cada paso es preguntarse siempre **¿Qué estoy haciendo y para qué lo hago?**

# %% [markdown]
# Apliquemos lo aprendido

# %% [markdown]
# # World Happiness Data

# %% [markdown]
# Datos obtenidos de: https://www.kaggle.com/mathurinache/world-happiness-report-20152021 y https://www.kaggle.com/ajaypalsinghlo/world-happiness-report-2021
#
#     Qué es lo primero que se debe hacer?
#     Antes de comenzar a estudiar el dataset, es necesario entender qué son las variables y de dónde proviene el dataset, junto con estudiar también:
#         ¿Cómo se mide el indice de felicidad?
#         ¿Qué este índice?
#         ¿Quiénes son les involucrades?
#         ¿Es el dataset fiable?
#
#     Es importante conocer bien de dónde provienen los datos, hay que saber con qué se está trabajando!
#
#     En kaggle aparece la descripción del dataset de la siguiente forma:

# %% [markdown]
# Lo siguiente es su descripción en Kaggle:

# %% [markdown]
#     Content
#     The joy scores and rankings utilize information from the Gallup World Survey. The scores are based on answers to the most life evaluation address inquired within the survey. This address, known as the Cantril step, asks respondents to think of a step with the most excellent conceivable life for them being a 10 and the most exceedingly bad conceivable life being a and to rate their claim current lives on that scale. The scores are from broadly agent tests for the a long time 2013-2016 and utilize the Gallup weights to create the gauges agent. The columns taking after the bliss score assess the degree to which each of six variables – financial generation, social back, life anticipation, flexibility, nonattendance of debasement, and liberality – contribute to making life assessments higher in each nation than they are in Dystopia, a theoretical nation that has values rise to to the world’s least national midpoints for each of the six variables. They have no affect on the full score detailed for each nation, but they do exp
#
#     This file contains the Happiness Score for 153 countries along with the factors used to explain the score.
#
#     The Happiness Score is a national average of the responses to the main life evaluation question asked in the Gallup World Poll (GWP), which uses the Cantril Ladder.
#
#     The Happiness Score is explained by the following factors:
#
#     GDP per capita
#     Healthy Life Expectancy
#     Social support
#     Freedom to make life choices
#     Generosity
#     Corruption Perception
#     Residual error
#     The data is described in much more detail here: link

# %% [markdown]
# # Preliminares

# %% [markdown]
# ## Importación de Librerías

# %%
from sklearn.cluster import KMeans 
from sklearn import metrics
from sklearn import cluster, datasets
from sklearn.metrics import silhouette_samples, silhouette_score

import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import sklearn
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

import matplotlib.patches as mpatches

# %% [markdown]
# ## Parámetros Generales

# %%
#Parámetros para mejorar la visualización de los dataframes
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 50)

# Parámetros para gráficos
plt.style.use('seaborn')

plt.rcParams.update({'font.size': 25})      
plt.rc('axes', labelsize=20)
plt.rc('legend', fontsize=18)  
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
plt.rcParams['axes.titlesize'] = 25
plt.rcParams["figure.figsize"] = (15,6)

# %% [markdown]
# # Primer Acercamiento a los datos

# %% [markdown]
# ## Carga y algunos números

# %% [markdown]
# Se cargan los datos

# %%
# Dataset solo con la data de 2021
df_2021 = pd.read_csv('data/world-happiness-report-2021.csv')

# Dataset con datos historicos
df = pd.read_csv('data/DataPanelWHR2021C2.csv')

# %% [markdown]
# Utilizamos el método _head_ para observar el dataset

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  \
# 0  Afghanistan  2008        3.724
# 1  Afghanistan  2009        4.402
# 2  Afghanistan  2010        4.758
# 3  Afghanistan  2011        3.832
# 4  Afghanistan  2012        3.783
#
#    Log GDP per capita  Social support  \
# 0               7.370           0.451
# 1               7.540           0.552
# 2               7.647           0.539
# 3               7.620           0.521
# 4               7.705           0.521
#
#    Healthy life expectancy at birth  \
# 0                             50.80
# 1                             51.20
# 2                             51.60
# 3                             51.92
# 4                             52.24
#
#    Freedom to make life choices  Generosity  \
# 0                         0.718       0.168
# 1                         0.679       0.190
# 2                         0.600       0.121
# 3                         0.496       0.162
# 4                         0.531       0.236
#
# ...

# %% [markdown]
# Lo primero a realizar es conocer el tamaño, cantidad de datos nulos, duplicados, etc del dataset

# %%
print('El dataset tiene una cantidad \
de {} datos y {} variables'.format(df.shape[0],df.shape[1]))
# Out:
# El dataset tiene una cantidad de 1949 datos y 11 variables

# %% [markdown]
# Veamos qué columnas tiene el dataset

# %%
print(df.columns)
# Out:
# Index(['Country name', 'year', 'Life Ladder',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth',
#        'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption',
#        'Positive affect', 'Negative affect'],
#       dtype='object')

# %% [markdown]
# También podemos observar más detalladamente qué tipo de variables contiene el dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
# Country name                        1949 non-null object
# year                                1949 non-null int64
# Life Ladder                         1949 non-null float64
# Log GDP per capita                  1913 non-null float64
# Social support                      1936 non-null float64
# Healthy life expectancy at birth    1894 non-null float64
# Freedom to make life choices        1917 non-null float64
# Generosity                          1860 non-null float64
# Perceptions of corruption           1839 non-null float64
# Positive affect                     1927 non-null float64
# Negative affect                     1933 non-null float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 167.6+ KB

# %% [markdown]
# Notamos que existen algunos datos con filas nulas, veamos cuántos nulos tienen en sus columnas

# %%
df.isna().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %% [markdown]
# Identificamos que las columnas Generosity y Perceptions of corruption son las que más tienen datos nulos, las tenemos que tener en cuenta para después

# %% [markdown]
# Una de las cosas que pasa generalmente en los datasets es que vienen datos duplicados, veremos si es que existen

# %%
# df.duplicated().sum() == 0
print('{} Existen datos duplicados'.format(list(map(lambda x: 'No' if x.duplicated().sum() == 0 else 'Si',
                                           [df]))[0]))
# Out:
# No Existen datos duplicados

# %% [markdown]
# Notar que el método anterior solo nos dice que dos filas, con todas las columnas, no están repetidas

# %% [markdown]
# Bueno, todas estos previos son bastante estandar, y no son especiales por cada dataset, son más bien generales. Estudiemos ahora el dataset como tal.

# %% [markdown]
# ## Exploración del dataset

# %% [markdown]
# Lo más importante, es tener en cuenta qué es lo que hay en el dataset, veamos

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  \
# 0  Afghanistan  2008        3.724
# 1  Afghanistan  2009        4.402
# 2  Afghanistan  2010        4.758
# 3  Afghanistan  2011        3.832
# 4  Afghanistan  2012        3.783
#
#    Log GDP per capita  Social support  \
# 0               7.370           0.451
# 1               7.540           0.552
# 2               7.647           0.539
# 3               7.620           0.521
# 4               7.705           0.521
#
#    Healthy life expectancy at birth  \
# 0                             50.80
# 1                             51.20
# 2                             51.60
# 3                             51.92
# 4                             52.24
#
#    Freedom to make life choices  Generosity  \
# 0                         0.718       0.168
# 1                         0.679       0.190
# 2                         0.600       0.121
# 3                         0.496       0.162
# 4                         0.531       0.236
#
# ...

# %% [markdown]
# Observamos que hay una variable de país y otra de año, lo cual, inmediatamente sabemos que tenemos datos históricos del índice de felicidad y podremos hacer comparaciones en los años de los países. Veamos cuántos años hay

# %%
df['Country name'].nunique()
# Out:
# 166

# %%
df['year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2007, 2020, 2006, 2005])

# %%
df['year'].value_counts(sort=False)
# Out:
# 2005     27
# 2006     89
# 2007    102
# 2008    110
# 2009    114
# 2010    124
# 2011    146
# 2012    142
# 2013    137
# 2014    145
# 2015    143
# 2016    142
# 2017    147
# 2018    142
# 2019    144
# 2020     95
# Name: year, dtype: int64

# %% [markdown]
# Interesante! tenemos que en el año 2020 hay menos paises en los datos.
#
# ¿qué hacemos?
#
# Es muy importante investigar de dónde vienen los datos y qué tenemos realmente. Después de una investigación, se tiene que estos datos fueron utilizados para hacer una tabla puntual de lo que es todo el reporte, con lo cual solo viene una parte de la data completa. Buscando en las mismas fuentes, se encontró el resto de datos desde el 2020 hasta el 2021, con lo cual se importan dos nuevos datasets

# %%
df_2020 = pd.read_csv('data/2020.csv')
df_2021 = pd.read_csv('data/2021.csv')

df_2020['year'] = 2020
df_2021['year'] = 2021

# %%
df_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  \
# 0                        0.031156      7.869766
# 1                        0.033492      7.711245
# 2                        0.035014      7.628528
# 3                        0.059616      7.621347
# 4                        0.034837      7.556281
#
#    lowerwhisker  Logged GDP per capita  \
# 0      7.747634              10.639267
# 1      7.579955              10.774001
# 2      7.491272              10.979933
# 3      7.387653              10.772559
# 4      7.419719              11.087804
#
#    Social support  Healthy life expectancy  \
# 0        0.954330                71.900825
# 1        0.955991                72.402504
# ...

# %%
print(df_2020.shape)
# Out:
# (153, 21)

# %% [markdown]
# Hay más columnas! como en verdad nos interesa completar el dataset histórico, seleccionamos las columnas que nos interesan del dataset historico:

# %%
set_cols = [
    'Country name', 'year', 'Life Ladder',
    'Log GDP per capita', 'Social support',
    'Healthy life expectancy at birth',
    'Freedom to make life choices',
    'Generosity', 'Perceptions of corruption'
#     'Positive affect', 'Negative affect'
]

# %% [markdown]
# Vemos qué columnas corresponden a los nuevos datasets, dado que vienen con diferentes nombres

# %%
set_cols_2 = [
    'Country name', 
#     'Regional indicator', Columna interesante!
    'Ladder score',
#     'Standard error of ladder score',
#     'upperwhisker', 'lowerwhisker',
    'Logged GDP per capita', 'Social support',
    'Healthy life expectancy',
    'Freedom to make life choices',
    'Generosity', 'Perceptions of corruption',
#     'Ladder score in Dystopia',
#     'Explained by: Log GDP per capita',
#     'Explained by: Social support',
#     'Explained by: Healthy life expectancy',
#     'Explained by: Freedom to make life choices',
#     'Explained by: Generosity',
#     'Explained by: Perceptions of corruption',
#     'Dystopia + residual',
    'year'
]

# %% [markdown]
# Con esto, solo queda colocar los mismos nombres que el dataset historico y concatenar

# %%
df = df.rename(columns = {'Life Ladder':'Ladder score',
                       'Healthy life expectancy at birth': 'Healthy life expectancy',
                         'Log GDP per capita': 'Logged GDP per capita'})

df = pd.concat((df.loc[df['year']!=2020], 
                df_2020[set_cols_2], 
                df_2021[set_cols_2]))
# Out:
# /home/fvasquez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys

# %% [markdown]
# y seleccionamos solo las columnas que son de nuestro interes, por ahora

# %%
df_hist = df[set_cols_2]

# %%
df_hist.head()
# Out:
#   Country name  Ladder score  \
# 0  Afghanistan         3.724
# 1  Afghanistan         4.402
# 2  Afghanistan         4.758
# 3  Afghanistan         3.832
# 4  Afghanistan         3.783
#
#    Logged GDP per capita  Social support  \
# 0                  7.370           0.451
# 1                  7.540           0.552
# 2                  7.647           0.539
# 3                  7.620           0.521
# 4                  7.705           0.521
#
#    Healthy life expectancy  \
# 0                    50.80
# 1                    51.20
# 2                    51.60
# 3                    51.92
# 4                    52.24
#
#    Freedom to make life choices  Generosity  \
# 0                         0.718       0.168
# 1                         0.679       0.190
# 2                         0.600       0.121
# 3                         0.496       0.162
# 4                         0.531       0.236
#
#    Perceptions of corruption  year
# 0                      0.882  2008
# ...

# %%
df_hist.shape
# Out:
# (2156, 9)

# %% [markdown]
# ## Preparando Datos históricos

# %% [markdown]
# Veamos algunos valores que pueden ser de interes. Antes que nada, se debe decidir qué hacer con los años y los datos faltantes.

# %%
df_hist.year.value_counts().reset_index().sort_values(by='index')
# Out:
#     index  year
# 16   2005    27
# 15   2006    89
# 14   2007   102
# 13   2008   110
# 12   2009   114
# 11   2010   124
# 3    2011   146
# 9    2012   142
# 10   2013   137
# 4    2014   145
# 6    2015   143
# 8    2016   142
# 2    2017   147
# 7    2018   142
# 5    2019   144
# 0    2020   153
# 1    2021   149

# %% [markdown]
# solo se seleccionarán los años entre 2015 y 2021, solo para comprar años recientes

# %%
df_hist = df_hist.loc[df_hist['year'].isin(range(2015,2022))]

# %% [markdown]
# Veamos cuántos nulos hay

# %%
df_hist.isna().sum()
# Out:
# Country name                     0
# Ladder score                     0
# Logged GDP per capita           19
# Social support                   2
# Healthy life expectancy         22
# Freedom to make life choices     8
# Generosity                      23
# Perceptions of corruption       47
# year                             0
# dtype: int64

# %%
# df_hist.loc[df_hist['Perceptions of corruption'].isna()]

# %% [markdown]
# Aquí tenemos una dificil decisión. Existen métodos para la completación de datos, pero en verdad como nos interesa poder realizar una exploración preliminar de los datos, los eliminaremos, hay que tener cuidado de obtener qué paises tienen algun dato nulo, para eliminar los paises en todos los años

# %%
borrar_paises = df_hist.loc[(df_hist['Perceptions of corruption'].isna()) |
                            (df_hist['Healthy life expectancy'].isna()) |
                            (df_hist['Freedom to make life choices'].isna())|
                            (df_hist['Generosity'].isna())|
                            (df_hist['Logged GDP per capita'].isna())]['Country name'].unique()

# %%
df_hist = df_hist.loc[~df_hist['Country name'].isin(borrar_paises)]

# %% [markdown]
# Además, tenemos que ver si es que tenemos los datos de todos los países en todos los años

# %%
df_hist['year'].value_counts()
# Out:
# 2020    128
# 2021    125
# 2017    124
# 2018    122
# 2019    121
# 2015    119
# 2016    117
# Name: year, dtype: int64

# %% [markdown]
# Debemos eliminar nuevamente algunos países

# %%
pais_completo = df_hist.groupby('Country name').size().reset_index()
pais_completo['Si'] = (pais_completo[0] == 7).astype(int)

pais_completo = pais_completo.loc[pais_completo['Si'] == 1]['Country name'].unique()

# %%
df_hist = df_hist.loc[df_hist['Country name'].isin(pais_completo)]

# %%
df_hist.loc[df_hist['Country name'] == 'Chile']
# Out:
#     Country name  Ladder score  \
# 336        Chile        6.5330
# 337        Chile        6.5790
# 338        Chile        6.3200
# 339        Chile        6.4360
# 340        Chile        5.9420
# 38         Chile        6.2285
# 42         Chile        6.1720
#
#      Logged GDP per capita  Social support  \
# 336              10.070000        0.827000
# 337              10.074000        0.841000
# 338              10.072000        0.880000
# 339              10.097000        0.890000
# 340              10.095000        0.869000
# 38               10.032055        0.879714
# 42               10.071000        0.882000
#
#      Healthy life expectancy  \
# 336                 69.60000
# 337                 69.70000
# 338                 69.80000
# 339                 69.90000
# 340                 70.00000
# 38                  69.90062
# 42                  70.00000
#
#      Freedom to make life choices  Generosity  \
# 336                      0.769000    0.041000
# ...

# %% [markdown]
# Ahora recién podemos hacer algunas visualizaciones

# %% [markdown]
# ## Visualizaciones

# %%
df_hist.isna().sum()
# Out:
# Country name                    0
# Ladder score                    0
# Logged GDP per capita           0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# year                            0
# dtype: int64

# %%
df_hist.describe()
# Out:
#        Ladder score  Logged GDP per capita  \
# count    756.000000             756.000000
# mean       5.573852               9.447214
# std        1.131317               1.171989
# min        2.375000               6.842167
# 25%        4.771125               8.498290
# 50%        5.650500               9.606500
# 75%        6.348725              10.423000
# max        7.858000              11.648000
#
#        Social support  Healthy life expectancy  \
# count      756.000000               756.000000
# mean         0.812428                64.896359
# std          0.121593                 7.068557
# min          0.420000                46.000000
# 25%          0.736913                59.104070
# 50%          0.843157                66.600000
# 75%          0.912250                71.100747
# max          0.987000                77.100000
#
#        Freedom to make life choices  Generosity  \
# count                    756.000000  756.000000
# ...

# %%
def plot_mean_col_by_year(df, col):
    fig, ax = plt.subplots()
    
    ax = df.groupby('year')[col].mean().plot()
    
    ax.set_title('Promedio en los años de {}'.format(col))
    ax.set_ylabel('Mean {}'.format(col))
    min_ = df[col].min()
    max_ = df[col].max()
    ax.set_ylim(min_, max_)
    plt.show()

# %%
plot_mean_col_by_year(df_hist, 'Ladder score')

# %%
plot_mean_col_by_year(df_hist, 'Social support')

# %%
plot_mean_col_by_year(df_hist, 'Perceptions of corruption')

# %% [markdown]
# Veamos algunas relaciones entre las variables, solo para un mismo año

# %%
df_hist_2021 = df_hist.loc[df_hist['year'] == 2021]

# %%
df_hist_2021.columns
# Out:
# Index(['Country name', 'Ladder score',
#        'Logged GDP per capita', 'Social support',
#        'Healthy life expectancy',
#        'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption',
#        'year'],
#       dtype='object')

# %%
sns.jointplot(x='Ladder score', 
              y='Logged GDP per capita',
              data=df_hist_2021, kind='reg')

# %%
sns.jointplot(x='Ladder score', 
              y='Healthy life expectancy',
              data=df_hist_2021, kind='reg')

# %%
fig = plt.figure(figsize=(15,15))
sns.pairplot(df_hist_2021[[
            'Ladder score',
            'Logged GDP per capita', 'Social support',
            'Healthy life expectancy']], 
#              height=15, aspect=0.6, 
             kind='reg')

# %%
fig = plt.figure(figsize=(15,15))
sns.pairplot(df_hist_2021[[
            'Ladder score',
            'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption']], 
#              height=15, aspect=0.6, 
             kind='reg')

# %% [markdown]
# # Modelos

# %% [markdown]
# ## KMeans

# %%
range_clusters_SSE = range(1,15)
range_clusters = range(2,15)

# %%
def SSE_AVGS(dataset):
    sse_kmeans = []
    vec_prom_kmeans=[]

    for k in range_clusters_SSE:
        kmeans = KMeans(n_clusters=k, random_state=1)
        kmeans.fit(dataset)
        sse_kmeans.append(kmeans.inertia_)
        if k>=2:
            silhouette_avg = silhouette_score(dataset,
                                              kmeans.fit_predict(dataset) )
            vec_prom_kmeans.append(silhouette_avg)
    return sse_kmeans, vec_prom_kmeans

# %%
def FuncionPlot(sse, vec_prom):
    f, (ax1, ax2) = plt.subplots(1, 2)
    plt.figure(figsize = (15,10))

    ax2.plot(range_clusters_SSE, sse)
    ax1.set_xlabel('Número de Clusters')
    ax1.set_ylabel('Promedio Score Silueta')
    ax1.set_title('Promedio Score Silueta por K Clusters',
             fontsize = 20)

    ax1.plot(range_clusters, vec_prom)
    ax2.set_xlabel('Número de Clusters')
    ax2.set_ylabel('Valor SSE')
    ax2.set_title('Valor SSE por número de clusters',
             fontsize = 20)

# %%
def predic_kmeans_plot(dataset, ncluster):
    
    kmeans = KMeans(n_clusters = ncluster, random_state=1)
    kmeans.fit(dataset)
    cluster_pred = kmeans.fit_predict(dataset)
    
    pca = PCA(n_components=dataset.shape[1])
    pca_result = pca.fit_transform(dataset)
    suma = np.cumsum(pca.explained_variance_ratio_)
    pca_data = pca.transform(dataset)
    
    per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
    labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
    
    pca_df = pd.DataFrame(pca_data, columns=labels)
    
    pca_df['Cluster'] = cluster_pred
    for i in range(0,ncluster):
        pca_df.loc[pca_df.Cluster == i,'Cluster'] = 'Cluster {}'.format(i)

    fig, ax = plt.subplots()
    
    sns.scatterplot(pca_df.PC1, pca_df.PC2, hue = pca_df['Cluster'])
    
    plt.title('ACP aplicado a todos los datos',fontsize=30)
    plt.xlabel('PC1 - Var. Exp.: {0}%'.format(per_var[0]),fontsize=25)
    plt.ylabel('PC2 - Var. Exp.: {0}%'.format(per_var[1]),fontsize=25)
    plt.show()
    return pca_df['Cluster']

# %%
df_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  \
# 0                           0.032         7.904
# 1                           0.035         7.687
# 2                           0.036         7.643
# 3                           0.059         7.670
# 4                           0.027         7.518
#
#    lowerwhisker  Logged GDP per capita  \
# 0         7.780                 10.775
# 1         7.552                 10.933
# 2         7.500                 11.117
# 3         7.438                 10.878
# 4         7.410                 10.932
#
#    Social support  Healthy life expectancy  \
# 0           0.954                     72.0
# 1           0.954                     72.7
# ...

# %%
sse_blobs, avg_sil_blobs = SSE_AVGS(df_hist_2021.drop(['Country name', 'year'], axis = 1))
FuncionPlot(sse_blobs, avg_sil_blobs)

# %%
labels = predic_kmeans_plot(df_hist_2021.drop(['Country name', 'year'], axis = 1), 3)

# %%
df_hist_2021_escalado = StandardScaler().fit_transform(df_hist_2021.drop(['Country name', 'year'], axis = 1))

# %%
sse_blobs, avg_sil_blobs = SSE_AVGS(df_hist_2021_escalado)
FuncionPlot(sse_blobs, avg_sil_blobs)

# %%
labels = predic_kmeans_plot(df_hist_2021_escalado, 3)

# %%
df_hist_km = df_hist_2021.copy()
df_hist_km = df_hist_km.reset_index()
df_hist_km['Cluster'] = labels

# %%
df_hist_km.Cluster.value_counts()
# Out:
# Cluster 0    56
# Cluster 1    33
# Cluster 2    19
# Name: Cluster, dtype: int64

# %%
def PCA_apply(df, vec):
    standard_datos = StandardScaler().fit(df)
    datos_norm = standard_datos.transform(df)
    
    pca = PCA(n_components=datos_norm.shape[1])
    pca_result = pca.fit_transform(datos_norm)
    suma = np.cumsum(pca.explained_variance_ratio_)
    pca_data = pca.transform(datos_norm)
    
    per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
    labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
    
    pca_df = pd.DataFrame(pca_data, index=df.index, columns=labels)
    
    plt.rcParams['figure.figsize'] = (15,8)
    
    fig, ax = plt.subplots()
    
    sns.scatterplot(pca_df.PC1, pca_df.PC2, hue = vec)
    
    plt.title('ACP aplicado a todos los datos',fontsize=30)
    plt.xlabel('PC1 - Var. Exp.: {0}%'.format(per_var[0]),fontsize=25)
    plt.ylabel('PC2 - Var. Exp.: {0}%'.format(per_var[1]),fontsize=25)

#     plt.savefig('graficos/ACP_datos.pdf', format = 'pdf', dpi = 600)
    plt.show()
    plt.rcParams.update({'font.size':15})
    
    df_pca_componentes = pd.DataFrame(pca.components_, columns = df.columns).T
    
    X = list(df_pca_componentes[0])
    Y = list(df_pca_componentes[1])
    nombres = df_pca_componentes.index
    
    for i, type in enumerate(nombres):
        x = X[i]
        y = Y[i]
        plt.scatter(x, y , marker = 'o')
        plt.text(x,y+0.01,type, fontsize = 17)

    
    plt.title('Contribución de Variables a Primeras 2 Componentes',fontsize=30)
    plt.xlabel('PC1 - Var. Exp.: {0}%'.format(per_var[0]),fontsize=25)
    plt.ylabel('PC2 - Var. Exp.: {0}%'.format(per_var[1]),fontsize=25)
    
#     plt.legend(handles=[blue_patch,green_patch,red_patch])
    plt.axhline(y = 0, alpha = 1)
    plt.axvline(x = 0, alpha = 1)
    plt.rcParams['figure.figsize'] = (15,8)

#     plt.savefig('graficos/ACP_varibles.pdf', format = 'pdf', dpi = 600)
    plt.show()

# %%
PCA_apply(df_hist_2021.drop(['Country name', 'year'], axis = 1),labels )

# %% [markdown]
# ##  Interpretación de resultados

# %%
df_hist_km.groupby(['year', 'Cluster'])['Ladder score'].mean()
# Out:
# year  Cluster
# 2021  Cluster 0    5.808375
#       Cluster 1    4.497970
#       Cluster 2    7.132632
# Name: Ladder score, dtype: float64

# %%
df_hist = df_hist.reset_index()

# %%
paises_cluster = df_hist_km[['Country name', 'Cluster']]

def labelizador_cluster(row):
    pais = row['Country name']
    cluster =list(paises_cluster.loc[paises_cluster['Country name']==pais]['Cluster'])[0]
#     print(cluster)
    return cluster

# %%
df_hist['Cluster'] = df_hist.apply(labelizador_cluster, axis=1)

# %%
def plot_mean_col_by_year_and_cluster(df, col):
#     fig, ax = plt.subplots()
    
    to_plot = df.groupby(['Cluster', 'year'])[col].mean().reset_index()

    to_plot.pivot(index = 'year', columns = 'Cluster', values=col).plot()
    
    plt.title('Promedio en los años de {}'.format(col))
    plt.ylabel('Mean {}'.format(col))
    min_ = df[col].min()
    max_ = df[col].max()
    plt.ylim(min_, max_)
    plt.show()

# %%
plot_mean_col_by_year_and_cluster(df_hist, 'Ladder score')

# %%
plot_mean_col_by_year_and_cluster(df_hist, 'Generosity')

# %%
plot_mean_col_by_year_and_cluster(df_hist, 'Social support')

# %%
plot_mean_col_by_year_and_cluster(df_hist, 'Perceptions of corruption')
